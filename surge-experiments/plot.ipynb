# %%
import matplotlib.pyplot as plt
import csv
import numpy

# %%
x=[]
y=[]
stats = numpy.loadtxt(open("stats-random-sharding.csv", "r"), delimiter=",")
print [1,2,3]
for i in range(0,4):
    x=list(stats[7*i:7*i+7, 2])
    y=list(stats[7*i:7*i+7, 3])
    print x,y
    plt.plot(x,y, marker='o')

plt.title('Random sharding')
plt.legend(['1,32', '2,16', '4,8', '8,4'], loc='upper left')
plt.xlabel('# of Clients')
plt.ylabel('TPS')

plt.show()
# Out:
# [1, 2, 3]
# [0.0, 50.0, 100.0, 150.0, 200.0, 250.0, 300.0] [0.0, 11.0350360944, 12.7198808215, 13.0670077896, 13.4060827497, 13.1996982051, 13.5401735659]
# [0.0, 50.0, 100.0, 150.0, 200.0, 250.0, 300.0] [0.0, 15.9224613354, 19.8215546666, 22.6466577975, 23.3899880429, 22.8378391799, 23.4889133626]
# [0.0, 50.0, 100.0, 150.0, 200.0, 250.0, 300.0] [0.0, 13.9575869194, 25.0170690053, 27.1139972384, 28.7221133561, 70.9560871512, 76.5723160692]
# [0.0, 50.0, 100.0, 150.0, 200.0, 250.0, 300.0] [0.0, 18.2082235992, 16.9064134591, 27.6633996527, 30.6580125823, 33.0008000186, 30.4759210566]

# %%
x=[]
y=[]
stats = numpy.loadtxt(open("stats-local-sharding.csv", "r"), delimiter=",")
print [1,2,3]
for i in range(0,4):
    x=list(stats[7*i:7*i+7, 2])
    y=list(stats[7*i:7*i+7, 3])
    print x,y
    plt.plot(x,y, marker='o')

plt.title('Random sharding')
plt.legend(['1,32', '2,16', '4,8', '8,4'], loc='upper left')
plt.xlabel('# of Clients')
plt.ylabel('TPS')

plt.show()
# Out:
# [1, 2, 3]
# [0.0, 50.0, 100.0, 150.0, 200.0, 250.0, 300.0] [0.0, 11.1545968794, 12.4294566848, 12.6336259011, 13.0340413515, 13.4690177179, 13.5339498274]
# [0.0, 50.0, 100.0, 150.0, 200.0, 250.0, 300.0] [0.0, 16.4452366652, 18.6656205658, 19.91282417, 22.4770117001, 21.9866815868, 21.8170204466]
# [0.0, 50.0, 100.0, 150.0, 200.0, 250.0, 300.0] [0.0, 16.4120710525, 21.1867637483, 25.5977585296, 66.7930344724, 29.2016027775, 28.8495325291]
# [0.0, 50.0, 100.0, 150.0, 200.0, 250.0, 300.0] [0.0, 35.1014394899, 17.9275179808, 18.8993090402, 25.8291278855, 28.1734113967, 27.9644197996]
